# %% [markdown]
# <a href="https://www.kaggle.com/code/hosseinbadrnezhad/simple-email-spam-detection?scriptVersionId=284870027" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
import numpy as np

# %%
emails = [
    "Buy now with an exclusive discount",      # spam
    "Big lottery – only today!",              # spam
    "Meeting tomorrow at 9 AM",               # normal
    "Your purchase invoice is ready"          # normal
]

labels = [1, 1, 0, 0]  # 1=spam, 0=normal

# %%
vec = CountVectorizer()
X = vec.fit_transform(emails)
X.shape, vec.get_feature_names_out(),vec.vocabulary_
# Out:
# ((4, 19),
#  array(['am', 'an', 'at', 'big', 'buy', 'discount', 'exclusive', 'invoice',
#         'is', 'lottery', 'meeting', 'now', 'only', 'purchase', 'ready',
#         'today', 'tomorrow', 'with', 'your'], dtype=object),
#  {'buy': 4,
#   'now': 11,
#   'with': 17,
#   'an': 1,
#   'exclusive': 6,
#   'discount': 5,
#   'big': 3,
#   'lottery': 9,
#   'only': 12,
#   'today': 15,
#   'meeting': 10,
#   'tomorrow': 16,
#   'at': 2,
#   'am': 0,
#   'your': 18,
#   'purchase': 13,
#   'invoice': 7,
#   'is': 8,
#   'ready': 14})

# %%
model = LogisticRegression()
model.fit(X, labels)
# Out:
# LogisticRegression()

# %%
test = ["Amazing discount today!"]
print("Spam probability:", model.predict_proba(vec.transform(test))[0][1])
# Out:
# Spam probability: 0.6071110470775809
